# %%
 a = input("Digite seu primeiro nome: ")
 b = input("Digite seu sobrenome: ")

 print("Seja bem vindo ", + a+ b ".")
# Out:
#   File "<ipython-input-14-a04554dda97e>", line 4
#     print("Seja bem vindo " + a + b ".")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
